# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
df = pd.read_csv("data/sales_small.csv")
df.head()
# Out:
#   Month Product  Region  Sales
# 0   Jan  Mobile    Pune  50000
# 1   Jan  Laptop  Mumbai  75000
# 2   Feb  Mobile    Pune  52000
# 3   Feb  Laptop  Mumbai  78000
# 4   Mar  Mobile    Pune  60000

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Month    10 non-null     object
#  1   Product  10 non-null     object
#  2   Region   10 non-null     object
#  3   Sales    10 non-null     int64
# dtypes: int64(1), object(3)
# memory usage: 452.0+ bytes
# Month      0
# Product    0
# Region     0
# Sales      0
# dtype: int64

# %%
# Total sales 
total_Sales = np.sum(df["Sales"])
print("total sales:", total_Sales)
# Out:
# total sales: 682000

# %%
# finding the average 
avg_sales = np.mean(df["Sales"])
print("Average sales: ", avg_sales)
# Out:
# Average sales:  68200.0

# %%
# product vice sales 
product_sales = df.groupby("Product")["Sales"].sum()
print(product_sales)
# Out:
# Product
# Laptop    400000
# Mobile    282000
# Name: Sales, dtype: int64

# %%
plt.figure(figsize=(8,5))
plt.plot(df["Month"], df["Sales"], marker='o')
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.grid(True)
plt.show()
